# %%
import pandas as pd
import numpy as np
import os
import fnmatch
import warnings
import json

# %%
def table(df):
    l = len(df.columns)
    df1 = df.iloc[:, :7]
    df_list = []
    for i in range(7, l, 3):
        df_i_0 = df.iloc[0:, i:i+3]
        df_i = pd.concat([df1, df_i_0],axis=1)
        df_i.columns = df_i.iloc[1]
        df_i['Старое наименование причала'] = df_i_0.columns[1]
        df_i['Новое наименование причала'] = df_i_0.iloc[0][1]
        df_i = df_i.rename(columns={df_i.columns[5]: 'Замена судна'})
        df_list.append(df_i.iloc[2:])

    df_con = df_list[0]
    for i in range(1, len(df_list)): 
        df_con = pd.concat([df_con,df_list[i]],axis=0)
    
    return df_con

def tables_in_file(file):
    sheets = pd.ExcelFile(file).sheet_names
    df_concat = pd.read_excel(file, sheet_name=sheets[1])
    df_concat = table(df_concat)
    for i in range(2, len(sheets)):
        df = pd.read_excel(file, sheet_name=sheets[i])
        df_concat = pd.concat([df_concat, table(df)], axis=0)
    datef = pd.to_datetime(file[11:21], format='%d.%m.%Y')
    df_concat['Дата подходов'] = datef.strftime('%Y-%m-%d')
    return df_concat

directory = "./"
files = []
files += os.listdir(directory)

file_list = []
for file in files:
    if fnmatch.fnmatch(file, 'Расписание*.xlsx'):
        file_list.append(file)

all_tables = tables_in_file(file_list[0])
for i in range(1, len(file_list)):
    all_tables = pd.concat([all_tables, tables_in_file(file_list[i])], axis=0)

# %%
all_tables
# Out:
# 1       Маршрут Лот Рейс                   Судовладелец     Судно  \
# 2      Северный   1    2             ООО "ТА "Мегафлот"       Рио
# 3      Северный   1    3             ООО "ТА "Мегафлот"       Рио
# 4      Северный   1    4             ООО "ТА "Мегафлот"       Рио
# 5      Северный   1    5             ООО "ТА "Мегафлот"       Рио
# 6      Северный   2    1            ООО "Все Теплоходы"   Радость
# ..          ...  ..  ...                            ...       ...
# 38  Коломенский  58    7  ИП Зыбин Сергей Александрович    Натали
# 2      Западный  65    1     ИП Бачурин Иван Алексеевич  Чижик-II
# 2      Западный  65    1     ИП Бачурин Иван Алексеевич  Чижик-II
# 2      Западный  65    1     ИП Бачурин Иван Алексеевич  Чижик-II
# 2      Западный  65    1     ИП Бачурин Иван Алексеевич  Чижик-II
#
# 1  Замена судна                          Комментарий ШВ               Подход  \
# 2           NaN                выходит по расписанию  В             11:27:00
# 3           NaN                выходит по расписанию  В             14:27:00
# 4           NaN                выходит по расписанию  В             17:27:00
# 5           NaN                выходит по расписанию  В             20:27:00
# 6       Счастье  выходит по расписанию с Китай-город  В             08:42:00
# ..          ...                                  ... ..                  ...
# 38          NaN                    не выходит в рейс  В  1900-01-01 00:10:00
# 2           NaN                    не выходит в рейс  А             10:37:00
# 2           NaN                    не выходит в рейс  А             12:24:00
# 2           NaN                    не выходит в рейс  А             12:34:00
# 2           NaN                    не выходит в рейс  А             14:34:00
#
# 1                 Отход Старое наименование причала  \
# 2              11:32:00            Киевский воказл
# 3              14:32:00            Киевский воказл
# 4              17:32:00            Киевский воказл
# 5              20:32:00            Киевский воказл
# 6              08:47:00            Киевский воказл
# ..                  ...                         ...
# 38  1900-01-01 00:15:00              Коломенское .1
# 2              10:44:00      Международная выставка
# 2              12:29:00            Серебряный Бор 2
# 2              12:44:00               Троице-Лыково
# 2              14:37:00    Международная выставка.1
#
# 1  Новое наименование причала Дата подходов
# 2                    Киевский    2023-07-01
# 3                    Киевский    2023-07-01
# 4                    Киевский    2023-07-01
# 5                    Киевский    2023-07-01
# 6                    Киевский    2023-07-01
# ..                        ...           ...
# 38               Коломенское     2023-07-31
# 2             Сити-Экспоцентр    2023-07-31
# 2            Серебряный Бор 2    2023-07-31
# 2               Троице-Лыково    2023-07-31
# 2             Сити-Экспоцентр    2023-07-31
#
# [59356 rows x 13 columns]

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=UserWarning)
    all_raz_tables = pd.read_excel(file_list[0], sheet_name='РАЗОВЫЕ')
    for i in range(1, len(file_list)):
        df_raz = pd.read_excel(file_list[i], sheet_name='РАЗОВЫЕ')
        df_raz = df_raz.rename(columns={df_raz.columns[5]: 'Дата подходов '})
        all_raz_tables = pd.concat([all_raz_tables, df_raz], axis=0)

all_raz_tables
# Out:
#          Наименование судовладельца       Судно Старое наименование причала  \
# 0                 ООО Все теплоходы   Жемчужина            Кленовый Бульвар
# 1                      ООО Адмиралъ    Адмиралъ                     Меловой
# 2                      ООО Адмиралъ        М-88                     Меловой
# 3                    ООО Ривер Сайт  Флибустьер                   Печатники
# 4    ИП Каплин Александр Евгеньевич     Ривьера                 Коломенское
# ..                              ...         ...                         ...
# 139                ООО Водное такси      Фараон               Третьяковский
# 140                ООО Водное такси      Фараон               Третьяковский
# 141                ООО Водное такси      Фараон               Третьяковский
# 142                ООО Водное такси      Фараон               Третьяковский
# 143                ООО Водное такси      Фараон               Третьяковский
#
#     Новое наименование причала Швартовое место Дата подходов  Время подхода  \
# 0             Кленовый Бульвар               А     2023-07-01      00:00:00
# 1                      Меловой               А     2023-07-01      00:00:00
# 2                      Меловой               А     2023-07-01      00:00:00
# 3                    Печатники               А     2023-07-01      00:00:00
# 4                 Коломенское                А     2023-07-01      00:00:00
# ..                         ...             ...            ...           ...
# 139              Третьяковский               В     2023-07-31      14:00:00
# 140              Третьяковский               В     2023-07-31      15:30:00
# 141              Третьяковский               В     2023-07-31      17:00:00
# 142              Третьяковский               В     2023-07-31      18:30:00
# 143              Третьяковский               В     2023-07-31      20:00:00
#
#     Время отхода     Комментарий  Передано в АИС Река
# 0       00:30:00     согласовано                  NaN
# 1       08:00:00  Ночная стоянка  Передано в АИС Река
# 2       08:00:00  Ночная стоянка  Передано в АИС Река
# 3       12:00:00  ночная стоянка                  NaN
# 4       08:00:00  Ночная стоянка                  NaN
# ..           ...             ...                  ...
# 139     14:30:00     согласовано                  NaN
# 140     16:00:00     согласовано                  NaN
# 141     17:30:00     согласовано                  NaN
# 142     19:00:00     согласовано                  NaN
# 143     20:30:00     согласовано                  NaN
#
# [4358 rows x 10 columns]

# %%
with pd.ExcelWriter('New_1.xlsx') as writer:
    all_raz_tables.to_excel(writer, sheet_name='РАЗОВОЕ', index=False)
    all_tables.to_excel(writer, sheet_name='РАЙОНЫ', index=False)

# %%
json_str1 = all_tables.to_json(orient='records', force_ascii=False)
json_str2 = all_raz_tables.to_json(orient='records', force_ascii=False)

with open('data.json', 'w', encoding='utf-8') as f:
    json.dump(json_str1, f, ensure_ascii=False, indent=4)
    json.dump(json_str2, f, ensure_ascii=False, indent=4)
